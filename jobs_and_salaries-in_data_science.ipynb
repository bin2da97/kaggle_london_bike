# %% [markdown]
# # 데이터셋 소개:
#
# **work_year**: 데이터 기록 연도입니다. 이 필드는 시간적 맥락을 나타내며 시간에 따른 급여 동향을 이해하는 데 중요합니다.
#
# **job_title**: 직책의 구체적인 제목입니다. 'Data Scientist', 'Data Engineer', 또는 'Data Analyst'와 같이 데이터 분야 내에서 다양한 전문 역할에 대한 급여 분포를 이해하는 데 중요한 열입니다.
#
# **job_category**: 직무 역할을 보다 넓은 범주로 분류하여 쉬운 분석을 위한 것입니다. 'Data Analysis', 'Machine Learning', 'Data Engineering'과 같은 범주로 구분될 수 있습니다.
#
# **salary_currency**: 급여가 지불되는 통화입니다. USD, EUR 등과 같이 급여를 글로벌 맥락에서의 실제 가치를 이해하는 데 중요합니다.
#
# **salary**: 현지 통화로 표시된 직책의 연간 총 급여입니다. 이 원시 급여 수치는 지역별 급여 비교에 중요한 역할을 합니다.
#
# **salary_in_usd**: 미국 달러(USD)로 변환된 연간 총 급여입니다. 이 통일된 통화 변환은 글로벌 급여 비교 및 분석을 돕습니다.
#
# **employee_residence**: 직원의 거주 국가입니다. 이 데이터는 지리적 급여 차이와 생활비 차이를 탐색하는 데 사용될 수 있습니다.
#
# **experience_level**: 직원의 전문 경험 수준을 분류합니다. 'Entry-level', 'Mid-level', 'Senior', 'Executive'와 같은 일반적인 범주가 있으며, 경험이 데이터 관련 역할의 급여에 어떻게 영향을 미치는지에 대한 통찰을 제공합니다.
#
# **employment_type**: 'Full-time', 'Part-time', 'Contract' 등과 같이 고용 유형을 지정합니다. 다른 고용 조건이 급여 구조에 어떤 영향을 미치는지를 분석하는 데 도움이 됩니다.
#
# **work_setting**: 'Remote', 'In-person', 'Hybrid'와 같이 작업 환경이나 환경을 나타냅니다. 이 열은 데이터 산업에서 작업 환경이 급여 수준에 어떻게 영향을 미치는지를 반영합니다.
#
# **company_location**: 회사의 위치가 있는 국가입니다. 회사의 위치가 급여 구조에 어떻게 영향을 미치는지를 분석하는 데 도움이 됩니다.
#
# **company_size**: 고용주 회사의 규모로, 종종 소형 (S), 중형 (M), 대형 (L) 크기로 분류됩니다. 이는 회사 크기가 급여에 어떤 영향을 미치는지를 분석하는 데 사용됩니다.

# %% [markdown]
# # 라이브러리 로드

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px 
import seaborn as sns
from plotly.offline import iplot , plot 
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터 불러오기 및 분석

# %%
df = pd.read_csv("/kaggle/input/jobs-in-data/jobs_in_data.csv")

# %%
df.sample(5) # sample 무작위 추출
# Out:
#       work_year           job_title               job_category  \
# 6378       2023  Analytics Engineer  Leadership and Management
# 4766       2023   Applied Scientist  Data Science and Research
# 2004       2023        Data Analyst              Data Analysis
# 81         2023  Research Scientist  Data Science and Research
# 6628       2023       Data Engineer           Data Engineering
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 6378             USD   87000          87000      United States
# 4766             USD  222200         222200      United States
# 2004             USD  100000         100000      United States
# 81               USD  165000         165000      United States
# 6628             USD  153600         153600      United States
#
#      experience_level employment_type work_setting company_location  \
# 6378           Senior       Full-time    In-person    United States
# 4766           Senior       Full-time    In-person    United States
# 2004           Senior       Full-time    In-person    United States
# 81          Mid-level       Full-time       Remote    United States
# 6628           Senior       Full-time    In-person    United States
#
#      company_size
# 6378            M
# 4766            L
# 2004            M
# 81              M
# 6628            M

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M

# %%
df.shape #9355행, 12 열
# Out:
# (9355, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# 모든 데이터 non-null \
# 정수형(int64)이 3개의 열에서 사용되고, 문자열(object)이 9개의 열에서 사용

# %%
# NaN 값 확인, 없음
df.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# 정수형 데이터 기초 통계 요약
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
# Describe all Data (숫자형 데이터를 제외한)
df.describe(exclude=np.number) # np.number는 NumPy 라이브러리에서 제공되는 숫자 데이터 타입들을 모두 포함하는 범용 클래스
# Out:
#             job_title               job_category salary_currency  \
# count            9355                       9355            9355
# unique            125                         10              11
# top     Data Engineer  Data Science and Research             USD
# freq             2195                       3014            8591
#
#        employee_residence experience_level employment_type work_setting  \
# count                9355             9355            9355         9355
# unique                 83                4               4            3
# top         United States           Senior       Full-time    In-person
# freq                 8086             6709            9310         5730
#
#        company_location company_size
# count              9355         9355
# unique               70            3
# top       United States            M
# freq               8132         8448

# %%
pd.DataFrame({'Count':df.shape[0],
              'Null':df.isnull().sum(),
              'Null %':df.isnull().mean() * 100,
              'Cardinality':df.nunique()
})
# Out:
#                     Count  Null  Null %  Cardinality
# work_year            9355     0     0.0            4
# job_title            9355     0     0.0          125
# job_category         9355     0     0.0           10
# salary_currency      9355     0     0.0           11
# salary               9355     0     0.0         1507
# salary_in_usd        9355     0     0.0         1786
# employee_residence   9355     0     0.0           83
# experience_level     9355     0     0.0            4
# employment_type      9355     0     0.0            4
# work_setting         9355     0     0.0            3
# company_location     9355     0     0.0           70
# company_size         9355     0     0.0            3

# %% [markdown]
#  - 9355 행
#  - 결측값 없음
#  - 각 열에 대한 고유값의 개수
#
# ### 고유값의 개수가 많을수록 카디널리티가 높다고 말합니다. 반면에 고유값의 개수가 적을수록 카디널리티가 낮습니다. 이 정보는 데이터셋을 이해하고 분석하는 데 중요한 통계적인 특성 중 하나입니다.
#
# ### 고유값의 개수가 의미하는 정보:
#
# - 고유값의 다양성 확인: 고유값이 많으면 해당 열이 다양한 값을 가지고 있음을 나타냅니다.
#
# - 범주형 데이터 탐색: 특히 범주형 열에서 유용합니다. 고유값의 개수가 적은 범주형 열은 해당 범주에 대한 분석이 상대적으로 간단할 수 있습니다.
#
# - 데이터 전처리 결정: 고유값이 많은 열은 처리가 필요한 경우가 있습니다. 예를 들어, 원-핫 인코딩을 적용하는 경우, 많은 고유값이 있는 열은 인코딩 결과가 매우 희소할 수 있습니다.
#
# - 이상치 감지: 특히 수치형 데이터에서는 고유값이 적은 열에서 이상치가 눈에 띄게 나타날 수 있습니다.

# %%
# Check Duplicated rows
df.duplicated().any() #True 중복된 열이 있음, False 없음
# Out:
# True

# %%
df.duplicated().sum() # 중복된 행의 갯수
# Out:
# 4014

# %%
df[df.duplicated()]
# Out:
#       work_year           job_title               job_category  \
# 64         2023        Data Analyst              Data Analysis
# 111        2023  Research Scientist  Data Science and Research
# 112        2023  Research Scientist  Data Science and Research
# 115        2023       Data Engineer           Data Engineering
# 116        2023       Data Engineer           Data Engineering
# ...         ...                 ...                        ...
# 9079       2022      Data Scientist  Data Science and Research
# 9080       2022       Data Engineer           Data Engineering
# 9081       2022       Data Engineer           Data Engineering
# 9214       2021       Data Engineer           Data Engineering
# 9314       2021      Data Scientist  Data Science and Research
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 64               USD   75000          75000      United States
# 111              USD  165000         165000      United States
# 112              USD  118800         118800      United States
# 115              USD  184000         184000      United States
# 116              USD  123000         123000      United States
# ...              ...     ...            ...                ...
# 9079             USD   78000          78000      United States
# 9080             USD  135000         135000      United States
# 9081             USD  115000         115000      United States
# 9214             USD  200000         200000      United States
# 9314             EUR   76760          90734            Germany
#
#      experience_level employment_type work_setting company_location  \
# 64        Entry-level       Full-time    In-person    United States
# 111         Mid-level       Full-time       Remote    United States
# 112         Mid-level       Full-time       Remote    United States
# 115         Mid-level       Full-time    In-person    United States
# 116         Mid-level       Full-time    In-person    United States
# ...               ...             ...          ...              ...
# 9079        Mid-level       Full-time       Remote    United States
# 9080           Senior       Full-time       Remote    United States
# 9081           Senior       Full-time       Remote    United States
# 9214        Mid-level       Full-time       Remote    United States
# 9314        Mid-level       Full-time       Hybrid          Germany
#
#      company_size
# 64              M
# 111             M
# 112             M
# 115             M
# 116             M
# ...           ...
# 9079            M
# 9080            M
# 9081            M
# 9214            L
# 9314            L
#
# [4014 rows x 12 columns]

# %% [markdown]
# # 데이터 전처리 및 분석

# %%
df.drop(['salary','company_location'],axis=1,inplace=True)
# 현지 통화 급여와 국가 데이터를 포함한 열을 삭제했다.
# 전세계적으로 공통된 기준으로 데이터를 분석(salary_in_usd) 🤔

# %%
# Delete Duplicated(중복 행 삭제)
df.drop_duplicates(inplace=True)

# %%
# Check Duplicated rows
df.duplicated().any() # 중복이 사라진 것을 확인
# Out:
# False

# %%
df.shape # 데이터 전처리 전 shape: 9355,12 -> 전처리 후 : 5341,10
# Out:
# (5341, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5341 entries, 0 to 9354
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5341 non-null   int64
#  1   job_title           5341 non-null   object
#  2   job_category        5341 non-null   object
#  3   salary_currency     5341 non-null   object
#  4   salary_in_usd       5341 non-null   int64
#  5   employee_residence  5341 non-null   object
#  6   experience_level    5341 non-null   object
#  7   employment_type     5341 non-null   object
#  8   work_setting        5341 non-null   object
#  9   company_size        5341 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 459.0+ KB

# %%
# Describe Numiric Data
df.describe()
# Out:
#          work_year  salary_in_usd
# count  5341.000000    5341.000000
# mean   2022.682082  146258.409099
# std       0.608026   66594.117529
# min    2020.000000   15000.000000
# 25%    2022.000000   98506.000000
# 50%    2023.000000  140000.000000
# 75%    2023.000000  186000.000000
# max    2023.000000  450000.000000

# %%
# Describe all Data
df.describe(exclude=np.number) #위에서 usd로 통화 기준을 통일했는데 salary_currency 도 필요없을거 같다🤔
# Out:
#             job_title               job_category salary_currency  \
# count            5341                       5341            5341
# unique            125                         10              11
# top     Data Engineer  Data Science and Research             USD
# freq             1100                       1655            4707
#
#        employee_residence experience_level employment_type work_setting  \
# count                5341             5341            5341         5341
# unique                 83                4               4            3
# top         United States           Senior       Full-time    In-person
# freq                 4255             3444            5296         2913
#
#        company_size
# count          5341
# unique            3
# top               M
# freq           4688

# %%
pd.DataFrame({'Count':df.shape[0],
              'Null':df.isnull().sum(),
              'Null %':df.isnull().mean() * 100,
              'Cardinality':df.nunique()
})
# Out:
#                     Count  Null  Null %  Cardinality
# work_year            5341     0     0.0            4
# job_title            5341     0     0.0          125
# job_category         5341     0     0.0           10
# salary_currency      5341     0     0.0           11
# salary_in_usd        5341     0     0.0         1786
# employee_residence   5341     0     0.0           83
# experience_level     5341     0     0.0            4
# employment_type      5341     0     0.0            4
# work_setting         5341     0     0.0            3
# company_size         5341     0     0.0            3

# %%
df.sample(5)
# Out:
#       work_year           job_title                    job_category  \
# 7035       2023  Research Scientist       Data Science and Research
# 3462       2023      Data Architect  Data Architecture and Modeling
# 2851       2023      Data Scientist       Data Science and Research
# 4455       2023      Data Scientist       Data Science and Research
# 3354       2023         AI Engineer         Machine Learning and AI
#
#      salary_currency  salary_in_usd employee_residence experience_level  \
# 7035             USD          85000      United States        Mid-level
# 3462             USD         180000      United States           Senior
# 2851             USD         226600      United States           Senior
# 4455             USD         206000      United States           Senior
# 3354             USD         227850      United States           Senior
#
#      employment_type work_setting company_size
# 7035       Full-time    In-person            M
# 3462       Full-time    In-person            M
# 2851       Full-time    In-person            M
# 4455       Full-time       Remote            M
# 3354       Full-time       Remote            M

# %% [markdown]
# # Work Year

# %%
# 각 연도별로 employees 수가 가장 많은 연도와 가장 적은 연도를 출력
print(f"Top Year for Number of Employees '{df['work_year'].value_counts().idxmax()}' with value '{df['work_year'].value_counts().max()}'")
print(f"Least Year for Number of Employees '{df['work_year'].value_counts().idxmin()}' with value '{df['work_year'].value_counts().min()}'")
# Out:
# Top Year for Number of Employees '2023' with value '3980'
# Least Year for Number of Employees '2020' with value '71'

# %% [markdown]
# #### 2020년 employees가 71개로 적었고
# #### 2023년도 들어서 3980개로 늘었다.

# %%
iplot(px.line(x = df['work_year'].value_counts().index,
              y = df['work_year'].value_counts().values,
              markers=True,
              labels={'x':'Year','y':'Number of Employees'},
              title='Years of Work',
              line_shape="linear",
              color_discrete_sequence=['#cc2114'],
              template='plotly_dark'
              ))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="704f5e5f-674a-490a-8e1f-c446cd7188d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("704f5e5f-674a-490a-8e1f-c446cd7188d6")) {                    Plotly.newPlot(                        "704f5e5f-674a-490a-8e1f-c446cd7188d6",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#cc2114","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2023,2022,2021,2020],"xaxis":"x","y":[3980,1095,195,71],"yaxis":"y","type":"scatter"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0, ...

# %% [markdown]
# 데이터 관련 직무에 종사하는 사람들은 전세계 적으로 증가하고 있는 추세이다.

# %%
# 국가별로 그룹화하여 연도별 총 직원 수를 계산
country_year_counts = df.groupby(['employee_residence', 'work_year']).size().reset_index(name='employee_count')
country_year_counts
# Out:
#     employee_residence  work_year  employee_count
# 0              Algeria       2022               1
# 1       American Samoa       2021               1
# 2              Andorra       2023               1
# 3            Argentina       2022               3
# 4            Argentina       2023               6
# ..                 ...        ...             ...
# 160      United States       2022             829
# 161      United States       2023            3310
# 162         Uzbekistan       2022               1
# 163         Uzbekistan       2023               2
# 164            Vietnam       2021               2
#
# [165 rows x 3 columns]

# %%
# Plotly Express를 사용하여 국가별로 연도에 따른 직원 수의 선 그래프를 그림
fig = px.line(
    country_year_counts,
    x='work_year',
    y='employee_count',
    color='employee_residence',
    labels={'work_year': 'Year', 'employee_count': 'Number of Employees'},
    title='Employee Count by Country and Year',
    line_shape="linear",
    template='plotly_dark'
)

# 그래프를 표시
fig.show()
# Out:
# <div>                            <div id="3fe24ef4-7f6a-4d02-a65a-8c20110e4c28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fe24ef4-7f6a-4d02-a65a-8c20110e4c28")) {                    Plotly.newPlot(                        "3fe24ef4-7f6a-4d02-a65a-8c20110e4c28",                        [{"hovertemplate":"employee_residence=Algeria\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","line":{"color":"#636efa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","orientation":"v","showlegend":true,"x":[2022],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=American Samoa\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Samoa","line":{"color":"#EF553B","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"American Samoa","orientation":"v","showlegend":true,"x":[2021],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Andorra\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","line":{"color":"#00cc96","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Andorra","orientation":"v","showlegend":true,"x":[2023],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Argentina\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","line":{"color":"#ab63fa","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","orientation":"v","showlegend":true,"x":[2022,2023],"xaxis":"x","y":[3,6],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Armenia\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","line":{"color":"#FFA15A","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Armenia","orientation":"v","showlegend":true,"x":[2023],"xaxis":"x","y":[2],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Australia\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","line":{"color":"#19d3f3","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","orientation":"v","showlegend":true,"x":[2021,2022,2023],"xaxis":"x","y":[2,8,9],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Austria\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","line":{"color":"#FF6692","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Austria","orientation":"v","showlegend":true,"x":[2020,2022,2023],"xaxis":"x","y":[2,3,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Belgium\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belgium","line":{"color":"#B6E880","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"Belgium","orientation":"v","showlegend":true,"x":[2021,2022,2023],"xaxis":"x","y":[2,3,1],"yaxis":"y","type":"scatter"},{"hovertemplate":"employee_residence=Bolivia\u003cbr\u003eYear=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bolivia","line":{"color":"#FF97FF","dash":"solid","shape":"linear"},"marker":{"symbol":"circle"},"mode":"lines","name":"B ...

# %% [markdown]
# # Job Title

# %%
df_job_title_USD = df.groupby('job_title')['salary_in_usd'].sum() # job_title에 대한 급여의 총합
df_job_title_USD
# Out:
# job_title
# AI Architect                       1401936
# AI Developer                       2540536
# AI Engineer                        5925803
# AI Programmer                       344087
# AI Research Engineer                293086
#                                     ...
# Sales Data Analyst                   60000
# Software Data Engineer              334883
# Staff Data Analyst                  239751
# Staff Data Scientist                269000
# Staff Machine Learning Engineer     185000
# Name: salary_in_usd, Length: 125, dtype: int64

# %%
print(f"Top Year for job_title of Employees '{df_job_title_USD.idxmax()}' with Salary '{df_job_title_USD.max()}'")
print(f"Least Year for job_title of Employees '{df_job_title_USD.idxmin()}' with Salary '{df_job_title_USD.min()}'")
# Out:
# Top Year for job_title of Employees 'Data Engineer' with Salary '157928139'
# Least Year for job_title of Employees 'BI Data Engineer' with Salary '60000'

# %%
iplot(px.bar(df_job_title_USD.sort_values(ascending=False),# 급여가 큰 순서대로 정렬하고, 
             orientation='h',
             labels={'value':'Salary in USD','job_title':'Job Title'},
             title='Job Title with Salaries USD',
             template='plotly_dark',
             color=df_job_title_USD.index,
             text_auto=True
))
# Out:
# <div>                            <div id="45355b01-3537-4c52-b713-9ed18db1fc9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45355b01-3537-4c52-b713-9ed18db1fc9c")) {                    Plotly.newPlot(                        "45355b01-3537-4c52-b713-9ed18db1fc9c",                        [{"alignmentgroup":"True","hovertemplate":"color=AI Architect\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Architect","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AI Architect","offsetgroup":"AI Architect","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[157928139],"xaxis":"x","y":["Data Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Developer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Developer","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AI Developer","offsetgroup":"AI Developer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[156404671],"xaxis":"x","y":["Data Scientist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Engineer","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AI Engineer","offsetgroup":"AI Engineer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[91457519],"xaxis":"x","y":["Machine Learning Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Programmer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Programmer","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"AI Programmer","offsetgroup":"AI Programmer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[80979778],"xaxis":"x","y":["Data Analyst"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Research Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Research Engineer","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AI Research Engineer","offsetgroup":"AI Research Engineer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[31773034],"xaxis":"x","y":["Analytics Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Scientist\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Scientist","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"AI Scientist","offsetgroup":"AI Scientist","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[28846982],"xaxis":"x","y":["Research Scientist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AWS Data Architect\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AWS Data Architect","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"AWS Data Architect","offsetgroup":"AWS Data Architect","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[21446529],"xaxis":"x","y":["Data Architect"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Analytics Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Analytics Engineer","marker":{"color":"#B6E880","pattern":{"sh ...

# %%
iplot(px.bar(df_job_title_USD.sort_values(ascending=False)[:10], # 상위 10개를 선택상위 10개 
             orientation='h',
             labels={'value':'Salary in USD','job_title':'Job Title'},
             title='Job Title with Salaries USD',
             template='plotly_dark',
             color=df_job_title_USD.index[:10],
             text_auto=True
))
# Out:
# <div>                            <div id="b84a05d5-d832-44bf-851f-0af62b5c336e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b84a05d5-d832-44bf-851f-0af62b5c336e")) {                    Plotly.newPlot(                        "b84a05d5-d832-44bf-851f-0af62b5c336e",                        [{"alignmentgroup":"True","hovertemplate":"color=AI Architect\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Architect","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AI Architect","offsetgroup":"AI Architect","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[157928139],"xaxis":"x","y":["Data Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Developer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Developer","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AI Developer","offsetgroup":"AI Developer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[156404671],"xaxis":"x","y":["Data Scientist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Engineer","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AI Engineer","offsetgroup":"AI Engineer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[91457519],"xaxis":"x","y":["Machine Learning Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Programmer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Programmer","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"AI Programmer","offsetgroup":"AI Programmer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[80979778],"xaxis":"x","y":["Data Analyst"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Research Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Research Engineer","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"AI Research Engineer","offsetgroup":"AI Research Engineer","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[31773034],"xaxis":"x","y":["Analytics Engineer"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AI Scientist\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AI Scientist","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"AI Scientist","offsetgroup":"AI Scientist","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[28846982],"xaxis":"x","y":["Research Scientist"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=AWS Data Architect\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AWS Data Architect","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"AWS Data Architect","offsetgroup":"AWS Data Architect","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[21446529],"xaxis":"x","y":["Data Architect"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Analytics Engineer\u003cbr\u003eSalary in USD=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Analytics Engineer","marker":{"color":"#B6E880","pattern":{"sh ...

# %% [markdown]
# - Top Earners:
#     - 데이터 엔지니어와 데이터 사이언티스트가 150M 이상의 급여로 가장 높은 수준의 보상을 받고 있습니다.
#
# - High Earners:
#     - 그 다음으로는 머신러닝 엔지니어와 데이터 분석가가 80M 이상의 급여를 받아 꾸준한 고소득을 유지하고 있습니다.
#
# - Diverse Roles:
#     - 데이터 분야에서 다양한 직종들이 다양한 수준의 급여를 받고 있습니다.
#     - 데이터 관련 직종들은 각자의 전문성과 경험에 따라 다르게 보상받고 있습니다.
#
# - Potential Trends:
#     - 급여의 편차와 트렌드를 조사하여 데이터 분야에서의 경향성을 확인할 수 있습니다.
#     - 업계에서 인기 있는 직종이나 특정 기술 스택을 보유한 직종들이 높은 보상을 받는 경향이 있을 수 있습니다.

# %% [markdown]
# # Job Category

# %%
df_job_category_general = df['job_category'].value_counts()
df_job_category_general
# Out:
# job_category
# Data Science and Research         1655
# Data Engineering                  1160
# Machine Learning and AI            917
# Data Analysis                      809
# Leadership and Management          351
# BI and Visualization               188
# Data Architecture and Modeling     162
# Data Management and Strategy        49
# Data Quality and Operations         45
# Cloud and Database                   5
# Name: count, dtype: int64

# %%
print(f"Top Job in Needed in 4 Years ago '{df_job_category_general.idxmax()}' with Value '{df_job_category_general.max()}'")
print(f"Least Job in Needed in 4 Years ago '{df_job_category_general.idxmin()}' with Value '{df_job_category_general.min()}'")
# Out:
# Top Job in Needed in 4 Years ago 'Data Science and Research' with Value '1655'
# Least Job in Needed in 4 Years ago 'Cloud and Database' with Value '5'

# %%
iplot(px.bar(df_job_category_general,
                 labels={'job_category':'Job Category'},
                 title=f"demand of Jobs Category in over the past 4 years", 
                 color_discrete_sequence=['#b3079c'],
                 template='plotly_dark',
                 text_auto=True
))
# Out:
# <div>                            <div id="7da29d3e-da78-4801-bb81-dbcb9f6810c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7da29d3e-da78-4801-bb81-dbcb9f6810c5")) {                    Plotly.newPlot(                        "7da29d3e-da78-4801-bb81-dbcb9f6810c5",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob Category=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#b3079c","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Data Science and Research","Data Engineering","Machine Learning and AI","Data Analysis","Leadership and Management","BI and Visualization","Data Architecture and Modeling","Data Management and Strategy","Data Quality and Operations","Cloud and Database"],"xaxis":"x","y":[1655,1160,917,809,351,188,162,49,45,5],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"his ...

# %% [markdown]
# - 데이터 과학 및 연구 분야가 가장 높은 수요를 기록하며, 현업에서의 과학적 탐구와 데이터 기반 의사 결정에 대한 높은 관심이 이어지고 있습니다.
# - 엔지니어링, 기계 학습, 인공 지능, 그리고 데이터 분석 분야가 뒤를 이어 높은 수요를 보이고 있어, 데이터 기술 분야의 성장과 혁신을 주도하고 있습니다.
# - 이러한 주요 분야를 지원하는 데이터 아키텍처, 모델링, 관리, 전략, 그리고 데이터 품질 및 운영 분야에서 전문가들의 필요성이 계속해서 높아지고 있습니다.

# %% [markdown]
# # Job Category In Each Year

# %%
df_job_category = df.groupby('work_year')['job_category'].value_counts()
df_job_category
# Out:
# work_year  job_category
# 2020       Data Science and Research           29
#            Data Engineering                    17
#            Data Analysis                       15
#            Machine Learning and AI             10
# 2021       Data Science and Research           71
#            Data Engineering                    44
#            Machine Learning and AI             37
#            Data Analysis                       28
#            Leadership and Management            9
#            Data Architecture and Modeling       5
#            Data Management and Strategy         1
# 2022       Data Science and Research          338
#            Data Engineering                   286
#            Data Analysis                      185
#            Machine Learning and AI            157
#            Leadership and Management           71
#            Data Architecture and Modeling      30
#            Data Management and Strategy        10
#            BI and Visualization                 8
#            Data Quality and Operations          8
#            Cloud and Database                   2
# 2023       Data Science and Research         1217
#            Data Engineering                   813
#            Machine Learning and AI            713
#            Data Analysis                      581
#            Leadership and Management          271
#            BI and Visualization               180
#            Data Architecture and Modeling     127
#            Data Management and Strategy        38
#            Data Quality and Operations         37
#            Cloud and Database                   3
# Name: count, dtype: int64

# %%
colors = ['#ccaa14','#8807b3','#07b324','#1007b3']
j = 0
for i in range(2020,2024):
    iplot(px.bar(df_job_category.get(i),
                 labels={'job_category':'Job Category','value':'Number of Employees'},
                 title=f"Needed of Jobs Category in {i}",
                 color_discrete_sequence=[colors[j]],
                 template='plotly_dark',
                 text_auto=True
                 ))
    j+=1
# Out:
# <div>                            <div id="e8e1d72c-7fb5-4548-9b1f-965debc45d56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8e1d72c-7fb5-4548-9b1f-965debc45d56")) {                    Plotly.newPlot(                        "e8e1d72c-7fb5-4548-9b1f-965debc45d56",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob Category=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#ccaa14","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Data Science and Research","Data Engineering","Data Analysis","Machine Learning and AI"],"xaxis":"x","y":[29,17,15,10],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"me ...
# <div>                            <div id="4af8b781-bfdd-496c-90c2-1020e3659558" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4af8b781-bfdd-496c-90c2-1020e3659558")) {                    Plotly.newPlot(                        "4af8b781-bfdd-496c-90c2-1020e3659558",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob Category=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#8807b3","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Data Science and Research","Data Engineering","Machine Learning and AI","Data Analysis","Leadership and Management","Data Architecture and Modeling","Data Management and Strategy"],"xaxis":"x","y":[71,44,37,28,9,5,1],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"s ...
# <div>                            <div id="76941fc5-d92d-4fc3-8fe4-e376336b84ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76941fc5-d92d-4fc3-8fe4-e376336b84ad")) {                    Plotly.newPlot(                        "76941fc5-d92d-4fc3-8fe4-e376336b84ad",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob Category=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#07b324","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Data Science and Research","Data Engineering","Data Analysis","Machine Learning and AI","Leadership and Management","Data Architecture and Modeling","Data Management and Strategy","BI and Visualization","Data Quality and Operations","Cloud and Database"],"xaxis":"x","y":[338,286,185,157,71,30,10,8,8,2],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...
# <div>                            <div id="6e1b83ef-fa54-4719-a424-4683d3b69be5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e1b83ef-fa54-4719-a424-4683d3b69be5")) {                    Plotly.newPlot(                        "6e1b83ef-fa54-4719-a424-4683d3b69be5",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eJob Category=%{x}\u003cbr\u003eNumber of Employees=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#1007b3","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Data Science and Research","Data Engineering","Machine Learning and AI","Data Analysis","Leadership and Management","BI and Visualization","Data Architecture and Modeling","Data Management and Strategy","Data Quality and Operations","Cloud and Database"],"xaxis":"x","y":[1217,813,713,581,271,180,127,38,37,3],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...

# %% [markdown]
# - 데이터 관련 분야의 수요는 매년 지속적으로 증가하고 있습니다. 특히, Data Science, Data Engineering, Machine Learning 및 AI, 그리고 Data Analysis 분야에서 높은 수요가 유지되고 있습니다.
#
# - 동시에, 새로운 분야들이 계속해서 등장하고 있습니다. Leadership 및 Management, BI 및 Visualization, Data Architecture 및 Modeling, Data Quality 및 Operations 등에서도 전문가들에 대한 수요가 높아지고 있습니다.

# %% [markdown]
# # Salary Currency

# %%
df_salary_currency = df['salary_currency'].value_counts()
df_salary_currency
# Out:
# salary_currency
# USD    4707
# EUR     282
# GBP     276
# CAD      37
# AUD      11
# PLN       7
# SGD       6
# CHF       5
# BRL       4
# TRY       3
# DKK       3
# Name: count, dtype: int64

# %%
print(f"Most Prefered Currency is '{df_salary_currency.idxmax()}'")
# Out:
# Most Prefered Currency is 'USD'

# %%
iplot(px.bar(df_salary_currency,
             template='plotly_dark',
             labels={'salary_currency':'Salary Currency','value':'Value'},
             title='Most Prefered Currency',
             text_auto=True,
             color_discrete_sequence=['#cce60e']

             ))
# Out:
# <div>                            <div id="423e54e5-9078-4923-b49c-3cf650f2f64e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("423e54e5-9078-4923-b49c-3cf650f2f64e")) {                    Plotly.newPlot(                        "423e54e5-9078-4923-b49c-3cf650f2f64e",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eSalary Currency=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#cce60e","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["USD","EUR","GBP","CAD","AUD","PLN","SGD","CHF","BRL","TRY","DKK"],"xaxis":"x","y":[4707,282,276,37,11,7,6,5,4,3,3],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoo ...

# %% [markdown]
# - 역시나 미국이 압도적

# %% [markdown]
# # Salary in USD

# %%
df_salary_in_usd = df.groupby(['work_year','job_title'])['salary_in_usd'].mean()
df_salary_in_usd
# Out:
# work_year  job_title
# 2020       AI Scientist               45896.000000
#            Azure Data Engineer       100000.000000
#            BI Data Analyst            98000.000000
#            Big Data Engineer          97690.333333
#            Business Data Analyst     110000.000000
#                                          ...
# 2023       Research Analyst           92625.083333
#            Research Engineer         181270.370787
#            Research Scientist        188089.740741
#            Software Data Engineer    111627.666667
#            Staff Data Analyst        179998.000000
# Name: salary_in_usd, Length: 244, dtype: float64

# %%
colors = ['#4a289b', '#a53d3d', '#268e7e', '#e60e0e']
j = 0
for i in range(2020,2024):
    iplot(px.bar(df_salary_in_usd.get(i)[:10],
                 labels={'job_title':'Job Title','value':'Mean of Salary'},
                 title=f"Mean Salary of Jobs for Year in {i}",
                 color_discrete_sequence=[colors[j]],
                 template='plotly_dark',
                 text_auto=True,
                 orientation='h'
                 ))
    j+=1
# Out:
# <div>                            <div id="ad00025c-21cd-423c-aa41-1464e255248e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad00025c-21cd-423c-aa41-1464e255248e")) {                    Plotly.newPlot(                        "ad00025c-21cd-423c-aa41-1464e255248e",                        [{"alignmentgroup":"True","hovertemplate":"variable=salary_in_usd\u003cbr\u003eMean of Salary=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"salary_in_usd","marker":{"color":"#4a289b","pattern":{"shape":""}},"name":"salary_in_usd","offsetgroup":"salary_in_usd","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[45896.0,100000.0,98000.0,97690.33333333333,110000.0,60000.0,60911.166666666664,93974.36363636363,103000.0,190200.0],"xaxis":"x","y":["AI Scientist","Azure Data Engineer","BI Data Analyst","Big Data Engineer","Business Data Analyst","Computer Vision Engineer","Data Analyst","Data Engineer","Data Science Consultant","Data Science Manager"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb ...
# <div>                            <div id="f4ff6109-f4d1-44b7-9843-e87e9e962fb5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4ff6109-f4d1-44b7-9843-e87e9e962fb5")) {                    Plotly.newPlot(                        "f4ff6109-f4d1-44b7-9843-e87e9e962fb5",                        [{"alignmentgroup":"True","hovertemplate":"variable=salary_in_usd\u003cbr\u003eMean of Salary=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"salary_in_usd","marker":{"color":"#a53d3d","pattern":{"shape":""}},"name":"salary_in_usd","offsetgroup":"salary_in_usd","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[42500.0,82137.5,230700.0,45555.0,101666.66666666667,99703.0,39000.0,57551.0,250000.0,124647.0],"xaxis":"x","y":["AI Scientist","Applied Data Scientist","Applied Machine Learning Scientist","Autonomous Vehicle Technician","BI Data Analyst","Big Data Architect","Big Data Engineer","Business Data Analyst","Cloud Data Architect","Cloud Data Engineer"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...
# <div>                            <div id="4479f520-6d61-43e2-91be-bdf70f1b2862" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4479f520-6d61-43e2-91be-bdf70f1b2862")) {                    Plotly.newPlot(                        "4479f520-6d61-43e2-91be-bdf70f1b2862",                        [{"alignmentgroup":"True","hovertemplate":"variable=salary_in_usd\u003cbr\u003eMean of Salary=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"salary_in_usd","marker":{"color":"#268e7e","pattern":{"shape":""}},"name":"salary_in_usd","offsetgroup":"salary_in_usd","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[275000.0,40000.0,36940.0,140815.0,138036.306122449,160800.0,98287.5,181963.63636363635,100500.0,61975.666666666664],"xaxis":"x","y":["AI Developer","AI Programmer","AI Research Engineer","AI Scientist","Analytics Engineer","Applied Data Scientist","Applied Machine Learning Scientist","Applied Scientist","BI Analyst","BI Data Analyst"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3 ...
# <div>                            <div id="06756131-5905-4f25-a65b-2656ba8ab198" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06756131-5905-4f25-a65b-2656ba8ab198")) {                    Plotly.newPlot(                        "06756131-5905-4f25-a65b-2656ba8ab198",                        [{"alignmentgroup":"True","hovertemplate":"variable=salary_in_usd\u003cbr\u003eMean of Salary=%{x}\u003cbr\u003eJob Title=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"salary_in_usd","marker":{"color":"#e60e0e","pattern":{"shape":""}},"name":"salary_in_usd","offsetgroup":"salary_in_usd","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x}","x":[233656.0,133266.82352941178,174288.32352941178,76021.75,85382.0,68498.14285714286,258000.0,158286.42405063292,399880.0,60526.75],"xaxis":"x","y":["AI Architect","AI Developer","AI Engineer","AI Programmer","AI Research Engineer","AI Scientist","AWS Data Architect","Analytics Engineer","Analytics Engineering Manager","Applied Data Scientist"],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778, ...

# %% [markdown]
# # Employee Residence

# %%
df_employee_residence = df['employee_residence'].value_counts() #근로자 거주지
df_employee_residence
# Out:
# employee_residence
# United States     4255
# United Kingdom     351
# Canada             196
# Germany             65
# Spain               63
#                   ...
# Andorra              1
# Qatar                1
# Mauritius            1
# Uganda               1
# Malta                1
# Name: count, Length: 83, dtype: int64

# %%
print(f"Top Country is '{df_employee_residence.idxmax()}' with value '{df_employee_residence.max()}'")
print(f"Least Country is '{df_employee_residence.idxmin()}' with value '{df_employee_residence.min()}'")
# Out:
# Top Country is 'United States' with value '4255'
# Least Country is 'Dominican Republic' with value '1'

# %%
iplot(px.bar(df_employee_residence[:10],
             template='plotly_dark',
             labels={'employee_residence':'Name of Country','value':'Value'},
             title='Top Country in the World in Data Science',
             text_auto=True,
             color_discrete_sequence=['#dd0be0'],
))
# Out:
# <div>                            <div id="ec1a4b2b-d746-4313-b085-e97f04cf6a1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec1a4b2b-d746-4313-b085-e97f04cf6a1d")) {                    Plotly.newPlot(                        "ec1a4b2b-d746-4313-b085-e97f04cf6a1d",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eName of Country=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#dd0be0","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["United States","United Kingdom","Canada","Germany","Spain","France","Portugal","Netherlands","Italy","Brazil"],"xaxis":"x","y":[4255,351,196,65,63,53,26,21,20,19],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outli ...

# %%
iplot(px.scatter_geo(df, 
                     locations='employee_residence',
                     locationmode='country names',
                     color='salary_in_usd',
                     hover_name='employee_residence',
                     title='Salary by Employee Residence',                    
))
# Out:
# <div>                            <div id="2fd689ba-0ca8-484e-8c58-140c0c0a1007" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fd689ba-0ca8-484e-8c58-140c0c0a1007")) {                    Plotly.newPlot(                        "2fd689ba-0ca8-484e-8c58-140c0c0a1007",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eemployee_residence=%{location}\u003cbr\u003esalary_in_usd=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Germany","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United Kingdom","United Kingdom","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","Canada","Canada","United Kingdom","United Kingdom","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United Kingdom","United Kingdom","United States","United States","United States","United States","United States","Canada","Canada","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United Kingdom","United Kingdom","Spain","Spain","United Kingdom","United Kingdom","Ireland","Canada","Canada","United States","United States","South Africa","South Africa","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","United States","Spain","Spain","United States","United States","Poland","Poland","United Kingdom","United States","United States","United States","United States","United States","United States","United States","United Kingdom","United Kingdom","United States","United States","United States","United States","Canada","Canada","United Kingdo ...

# %% [markdown]
# # Experience Level

# %%
df_experience_level = df['experience_level'].value_counts()

# %%
iplot(px.pie(values=df_experience_level.values,
             names=['Senior','Mid-level','Entry-level','Executive'],
             title='Experience Level for Data Analysts'
).update_traces(textinfo='percent+label'))
# Out:
# <div>                            <div id="800395ec-b8dc-4fc3-afd2-e1375baf8d1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("800395ec-b8dc-4fc3-afd2-e1375baf8d1d")) {                    Plotly.newPlot(                        "800395ec-b8dc-4fc3-afd2-e1375baf8d1d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Senior","Mid-level","Entry-level","Executive"],"legendgroup":"","name":"","showlegend":true,"textinfo":"percent+label","values":[3444,1274,400,223],"type":"pie"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d" ...
#
# var gd = document.

# %% [markdown]
# # Employment Type

# %%
df_employment_type = df['employment_type'].value_counts()
df_employment_type
# Out:
# employment_type
# Full-time    5296
# Contract       19
# Part-time      15
# Freelance      11
# Name: count, dtype: int64

# %%
iplot(px.bar(df_employment_type,
             template='plotly_dark',
             labels={'employment_type':'Employment Type','value':'Value'},
             title='Type of Employment for Data Analysts',
             text_auto=True,
             color_discrete_sequence=['#dd0be0'],
))
# Out:
# <div>                            <div id="c5b11a77-d36d-429d-9b2b-d8c916fe9ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5b11a77-d36d-429d-9b2b-d8c916fe9ad9")) {                    Plotly.newPlot(                        "c5b11a77-d36d-429d-9b2b-d8c916fe9ad9",                        [{"alignmentgroup":"True","hovertemplate":"variable=count\u003cbr\u003eEmployment Type=%{x}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"count","marker":{"color":"#dd0be0","pattern":{"shape":""}},"name":"count","offsetgroup":"count","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Full-time","Contract","Part-time","Freelance"],"xaxis":"x","y":[5296,19,15,11],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"title":{"text":"variable"},"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinew ...

# %% [markdown]
# # Work Setting

# %%
df_work_setting = df['work_setting'].value_counts()
df_work_setting
# Out:
# work_setting
# In-person    2913
# Remote       2239
# Hybrid        189
# Name: count, dtype: int64

# %%
iplot(px.pie(values=df_work_setting.values,
             names=['In-person','Remote','Hybrid'],
             title='Type of Work Setting',
).update_traces(textinfo='percent+label'))
# Out:
# <div>                            <div id="e1c6ddfc-47a3-4d4f-b808-f29db0ffdb9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1c6ddfc-47a3-4d4f-b808-f29db0ffdb9d")) {                    Plotly.newPlot(                        "e1c6ddfc-47a3-4d4f-b808-f29db0ffdb9d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["In-person","Remote","Hybrid"],"legendgroup":"","name":"","showlegend":true,"textinfo":"percent+label","values":[2913,2239,189],"type":"pie"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{ ...
#
# var gd = document.getElementById('e1c6ddfc-47a3-4d4f-

# %% [markdown]
# 생각보다 remote가 너무 많아서 혹시 코로나의 여파일지 알고싶어졌다

# %%
for i in range(2020,2024):
    print(df[df['work_year']==i]['work_setting'].value_counts())
# Out:
# work_setting
# Remote       35
# Hybrid       20
# In-person    16
# Name: count, dtype: int64
# work_setting
# Remote       106
# Hybrid        63
# In-person     26
# Name: count, dtype: int64
# work_setting
# Remote       608
# In-person    434
# Hybrid        53
# Name: count, dtype: int64
# work_setting
# In-person    2437
# Remote       1490
# Hybrid         53
# Name: count, dtype: int64

# %%
df.groupby(['work_year', 'work_setting']).size().unstack()
# Out:
# work_setting  Hybrid  In-person  Remote
# work_year
# 2020              20         16      35
# 2021              63         26     106
# 2022              53        434     608
# 2023              53       2437    1490

# %% [markdown]
# - 022년까지는 재택근무가 사무실 출근보다 더 많았다.
# - 재택근무보다 사무실 출근이 증가했다.
# - 이러한 변화는 코로나19 대응 조치의 완화 또는 다른 환경적인 변화로 인한 것으로 해석할 수 있다

# %% [markdown]
# # Company Size

# %%
df_company_size = df['company_size'].value_counts()
df_company_size
# Out:
# company_size
# M    4688
# L     495
# S     158
# Name: count, dtype: int64

# %%
iplot(px.pie(values=df_company_size.values,
             names=['M','L','S'],
             title='Size of Company',
).update_traces(textinfo='percent+label'))
# Out:
# <div>                            <div id="32d55147-dba0-4fdf-bf73-9c4ab7b03248" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32d55147-dba0-4fdf-bf73-9c4ab7b03248")) {                    Plotly.newPlot(                        "32d55147-dba0-4fdf-bf73-9c4ab7b03248",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["M","L","S"],"legendgroup":"","name":"","showlegend":true,"textinfo":"percent+label","values":[4688,495,158],"type":"pie"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar ...
#
# var gd = document.getElementById('32d55147-dba0-4fdf-bf73-9c4ab7b03248');
# var

# %% [markdown]
# - M 규모의 기업의 데이터 관련 직종에 대한 수요가 매우 컸다.
